# %% [markdown]
# <a href="https://colab.research.google.com/github/Marchisceddu/Progetto_Urbismap/blob/main/Progetto_Urbismap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you use colab
# %pip install Lightning
# %pip install segmentation_models_pytorch
# %pip install wget

# !git clone https://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@github.com/Marchisceddu/Progetto_Urbismap.git

# %cd Progetto_Urbismap

# %%
# Download save
import wget
wget.download("https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth", "finestSAM/sav")

# %%
# %run finestSAM/__main__.py --mode predict --input "../dataset2/images/0.png"
# Out:
# Seed set to 1337
# Predizioni Salvate
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
# %run finestSAM/__main__.py --mode train
# Out:
# Seed set to 1337
# loading annotations into memory...
# Done (t=0.74s)
# creating index...
# index created!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Progetto_Urbismap/finestSAM/__main__.py:29
#      22 # scrivere una funzione check per il file cfg
#      23
#      24 # Execute the selected mode
#      25 switcher = {
#      26     "train": call_train,
#      27     "predict": lambda cfg: automatic_predictions(cfg, predict_args.input, predict_args.approx_accuracy)
#      28 }
# ---> 29 switcher[args.mode](cfg)
#
# File ~/Progetto_Urbismap/finestSAM/model/train/train.py:42, in call_train(cfg)
#      34 loggers = [TensorBoardLogger(cfg.sav_dir, name="loggers_finestSAM")]
#      36 fabric = L.Fabric(accelerator=cfg.device,
#      37                   devices=cfg.num_devices,
#      38                   strategy="auto",
#      39                   num_nodes=cfg.num_nodes,
#      40                   loggers=loggers)
# ---> 42 fabric.launch(train, cfg)
#
# File ~/finestSAM/lib/python3.9/site-packages/lightning/fabric/fabric.py:859, in Fabric.launch(self, function, *args, **kwargs)
#     854 elif isinstance(self.strategy.launcher, (_MultiProcessingLauncher, _XLALauncher)):
#     855     raise TypeError(
#     856         f"To spawn processes with the `{type(self.strategy).__name__}` strategy, `.launch()` needs to be called"
#     857         " with a function that contains the code to launch in processes."
#     858     )
# --> 859 return self._wrap_and_launch(function, self, *args, **kwargs)
#
# File ~/finestSAM/lib/python3.9/site-packages/lightning/fabric/fabric.py:945, in Fabric._wrap_and_launch(self, to_run, *args, **kwargs)
#     943 if (launcher := self._strategy.launcher) is not None:
#     944     return launcher.launch(to_run, *args, **kwargs)
# --> 945 return to_run(*args, **kwargs)
#
# File ~/finestSAM/lib/python3.9/site-packages/lightning/fabric/fabric.py:950, in Fabric._wrap_with_setup(self, to_run, *args, **kwargs)
#     948 self._strategy.setup_environment()
#     949 with _replace_dunder_methods(DataLoader, "dataset"), _replace_dunder_methods(BatchSampler):
# --> 950     return to_run(*args, **kwargs)
#
# File ~/Progetto_Urbismap/finestSAM/model/train/train.py:74, in train(fabric, *args, **kwargs)
#      71 optimizer, scheduler = configure_opt(cfg, model)
#      72 model, optimizer = fabric.setup(model, optimizer)
# ---> 74 train_loop(cfg, fabric, model, optimizer, scheduler, train_data, val_data)
#
# File ~/Progetto_Urbismap/finestSAM/model/train/train.py:126, in train_loop(cfg, fabric, model, optimizer, scheduler, train_dataloader, val_dataloader)
#     123 epoch_metrics = Metrics()
#     124 end = time.time()
# --> 126 for iter, batched_data in enumerate(train_dataloader):
#     127     epoch_metrics.data_time.update(time.time()-end)
#     129     # Se presenti e selezionati dalle impostazioni passa i logits dell'epoca precedente
#
# File ~/finestSAM/lib/python3.9/site-packages/lightning/fabric/wrappers.py:296, in _FabricDataLoader.__iter__(self)
#     294     yield from iter(self._dataloader)
#     295 else:
# --> 296     for item in self._dataloader:
#     297         yield move_data_to_device(item, self._device)
#
# File ~/finestSAM/lib/python3.9/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/finestSAM/lib/python3.9/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/finestSAM/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 if self.auto_collation:
#      48     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
#      51         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/finestSAM/lib/python3.9/site-packages/torch/utils/data/dataset.py:419, in Subset.__getitems__(self, indices)
#     417     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     418 else:
# --> 419     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~/finestSAM/lib/python3.9/site-packages/torch/utils/data/dataset.py:419, in <listcomp>(.0)
#     417     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     418 else:
# --> 419     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~/Progetto_Urbismap/finestSAM/model/dataset5.py:276, in COCODataset.__getitem__(self, idx)
#     273         plt.show()
#     275         import time
# --> 276         time.sleep(10)
#     278 if self.transform:
#     279     image, resized_masks, boxes, point_coords = self.transform(image, masks, np.array(boxes), np.array(point_coords))
#
# KeyboardInterrupt:
